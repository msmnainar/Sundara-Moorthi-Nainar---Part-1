# %% [markdown]
# ## SECTION 1: Load Data

# %%
# Upload files
from google.colab import files
uploaded = files.upload()

import os
print("Uploaded files:", os.listdir())

import pandas as pd
customers = pd.read_csv("customers (9).csv")
orders = pd.read_csv("orders (9).csv")
support = pd.read_csv("support_tickets (9).csv")
web = pd.read_csv("web_events_snapshot (9).csv")
churn = pd.read_csv("churn_labels (9).csv")
campaign = pd.read_csv("intervention_history (9).csv")

print("✅ All files loaded successfully!")
customers.head()
